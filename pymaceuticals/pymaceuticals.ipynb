# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The study examined the effects of ten drug regimens on tumor growth in 249 mice, with each drug being tested on different timepoints to monitor tumor growth overtime.
# Capomulin and Ramicane were the most effective treatments for reducing tumor size, while Ketapril and Naftisol performed poorly, similar to the placebo. The high correlation between weight and tumor volume suggests a potential biological link that may influence treatment response.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_data_complete = pd.merge(study_results,mouse_metadata,how="left",on="Mouse ID")



# Display the data table for preview
mouse_data_complete.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
mice_count = mouse_data_complete["Mouse ID"].nunique()
mice_count
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
duplicate_miceid = mouse_data_complete[mouse_data_complete.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)]

# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_miceid["Mouse ID"].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicate_mice_data = mouse_data_complete.loc[mouse_data_complete["Mouse ID"]==duplicate_miceid["Mouse ID"].unique()[0]]
duplicate_mice_data
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_mouse_data = mouse_data_complete.drop(index=duplicate_mice_data.index)
clean_mouse_data.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
mice_count_clean_data = clean_mouse_data["Mouse ID"].nunique()
mice_count_clean_data
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

mean_tumor_volume = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()
median_tumor_volume = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].median()
variance_tumor_volume = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].var()
sd_tumor_volume = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].std()
sem_tumor_volume = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].sem()


# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.
summary_regimen = pd.DataFrame({
    'Mean Tumor Volume': mean_tumor_volume,
    'Median Tumor Volume': median_tumor_volume,
    'Tumor Volume Variance': variance_tumor_volume,
    'Tumor Volume Std. Dev.' : sd_tumor_volume,
    'Tumor Volume Std. Err.': sem_tumor_volume
})
summary_regimen
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.322552            50.854632              42.351070
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
agg_data = mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].agg(["mean","median","var","std","sem"])
agg_data
# and SEM of the tumor volume mouse_data_complete.groupby(["Drug Regimen"])["Tumor Volume (mm3)"].mean()for each regimen (only one method is required in the solution)
mouse_data_complete
# Using the aggregation method, produce the same summary statistics in a single line
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
regimen_counts = mouse_data_complete["Drug Regimen"].value_counts()
regimen_counts.plot(
    kind="bar",
    x = "Drug Regimen",
    y="Timepoint"
)
plt.ylabel(ylabel="# of Observed Mouse Timepoints")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.

regimen_counts = mouse_data_complete["Drug Regimen"].value_counts()
xpoints = regimen_counts.index
ypoints = regimen_counts.values

plt.bar(xpoints,ypoints)
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
plt.xticks(rotation = 90)
plt.show()

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study

# Get the unique mice with their gender
gender_counts = mouse_data_complete["Sex"].value_counts()
gender_counts.plot(
    kind="pie",
    autopct = "%1.1f%%"
    )
plt.ylabel(ylabel="Count")
plt.show()


# Make the pie chart

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study




# Get the unique mice with their gender
y = gender_counts.values
x = gender_counts.index



# Make the pie chart
plt.pie(y,labels=x,autopct = "%1.1f%%")
plt.ylabel("Counts")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
mouse_df = mouse_data_complete[mouse_data_complete['Drug Regimen'].isin(regimens)]
# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = mouse_df.groupby("Mouse ID")['Timepoint'].max().reset_index()
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
final_df = last_timepoint.merge(mouse_df, on=["Mouse ID","Timepoint"],how="left")
final_df
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]


# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []


# Calculate the IQR and quantitatively determine if there are any potential outliers.
for treatment in treatments:

    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_volume = final_df.loc[final_df["Drug Regimen"]==treatment]["Tumor Volume (mm3)"]


    # add subset
    tumor_vol_data.append(tumor_volume)


    # Determine outliers using upper and lower bounds
    quartiles = tumor_volume.quantile([.25,.5,.75])
    iqr = quartiles[.75] - quartiles[.25]
    lower_bound = quartiles[.25]-(1.5*iqr)
    upper_bound = quartiles[.75]+(1.5*iqr)
    outliers = []
    for value in tumor_volume:
        if value<lower_bound or value>upper_bound:
            outliers.append(value)

    print(f"{treatment}'s potential outliers: {outliers}")
# Out:
# Capomulin's potential outliers: []
# Ramicane's potential outliers: []
# Infubinol's potential outliers: [36.3213458]
# Ceftamin's potential outliers: []

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
plt.boxplot(tumor_vol_data,flierprops={
    "markerfacecolor": "red"
})
plt.xticks(ticks=range(1,len(treatments)+1),labels=treatments)
plt.ylabel(ylabel="Final Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Final Tumor Volume (mm3)')

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_df = mouse_data_complete[mouse_data_complete['Drug Regimen']=='Capomulin']
mouse_id = 'l509'
df = capomulin_df[capomulin_df["Mouse ID"]== mouse_id]
plt.plot(
    df["Timepoint"],df["Tumor Volume (mm3)"]
)
plt.ylabel(ylabel="Tumor Volume (mm3)")
plt.xlabel(xlabel="Timepoint(days)")
plt.title(f"Capomulin treatment of mouse {mouse_id}")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
average_tumor_volume = capomulin_df.groupby("Mouse ID")["Tumor Volume (mm3)"].mean().reset_index()
mouse_weight = capomulin_df[["Mouse ID","Weight (g)"]].drop_duplicates()
merge_df = average_tumor_volume.merge(mouse_weight,on="Mouse ID")
plt.scatter(
    merge_df["Weight (g)"],merge_df["Tumor Volume (mm3)"]
)
plt.ylabel(ylabel="Average Tumot Volume(mm3)")
plt.xlabel(xlabel="Weight(g)")
# Out:
# Text(0.5, 0, 'Weight(g)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
x = merge_df["Weight (g)"]
y = merge_df["Tumor Volume (mm3)"]

slope, intercept, r_value, p_value, std_err = st.linregress(x, y)
print(f"The correlation between mouse weight and the average tumor volume is {r_value:.2f}")
plt.scatter(x, y)
plt.plot(x, slope * x + intercept, color="red")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
